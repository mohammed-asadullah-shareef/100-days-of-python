# %% [markdown]
# # Day 1 Practice Set: Working with Variables, Input, and Printing
#
# Welcome to your first Practice Set! These exercises are designed to reinforce what you learned in Day 1.
#
# **Topics Covered:**
# * `print()`
# * Strings & Concatenation (`+`)
# * New Lines (`\n`)
# * `input()`
# * Variables
# * `len()`
#
# ---

# %% [markdown]
# ## 1. Warm-up: The Receipt Printer
#
# **Difficulty:** Easy
#
# **Goal:** Use the `print()` function and the newline character `\n` to format text.
#
# **Task:** Write a **single** line of code (using only one `print` statement) that outputs the following shopping list exactly as shown:
#
# ```text
# Shopping List:
# 	* Apples
# 	* Bananas
# 	* Bread
# ```
#
# *(Hint: `\t` creates a tab indentation, `\n` creates a new line)*

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# print("Shopping List:\n\t* Apples\n\t* Bananas\n\t* Bread")
# ```
# </details>

# %% [markdown]
# ## 2. Warm-up: The Echo Bot
#
# **Difficulty:** Easy
#
# **Goal:** Use `input()` and string concatenation.
#
# **Task:**
# 1. Ask the user "What is your favorite animal? "
# 2. Print a sentence that says: "Wow! A [animal] is a great choice!"
#
# **Example Output:**
# ```text
# What is your favorite animal? Tiger
# Wow! A Tiger is a great choice!
# ```

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# # Note: You can do this with or without a variable, but using a variable is cleaner.
# animal = input("What is your favorite animal? ")
# print("Wow! A " + animal + " is a great choice!")
# ```
# </details>

# %% [markdown]
# ## 3. Core Practice: The Variable Swapper 2.0
#
# **Difficulty:** Medium
#
# **Goal:** Understand variable assignment logic.
#
# **Task:** You have three variables: `a`, `b`, and `c`.
# * Currently: `a = 1`, `b = 2`, `c = 3`
# * Required Output: `a = 3`, `b = 1`, `c = 2`
#
# Write the code to shift the values (A takes C, B takes A, C takes B). You cannot assign numbers directly (e.g., `a = 3` is forbidden). You must use variables.

# %%
a = 1
b = 2
c = 3

# Write your code below this line 👇


# Write your code above this line 👆

print("a: " + str(a))
print("b: " + str(b))
print("c: " + str(c))

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# # We need a temporary variable to hold values while we swap them
# temp = a
# a = c
# c = b
# b = temp
#
# # Alternative logic implies a rotation:
# # temp = c (3)
# # c = b (2)
# # b = a (1)
# # a = temp (3)
# ```
# </details>

# %% [markdown]
# ## 4. Core Practice: Character Counter
#
# **Difficulty:** Medium
#
# **Goal:** Combine `input()`, `len()`, and variables.
#
# **Task:**
# 1. Ask the user for their favorite city.
# 2. Calculate the number of characters in that city name.
# 3. Print the number.
#
# **Example Output:**
# ```text
# Enter a city: London
# 6
# ```

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# city = input("Enter a city: ")
# length = len(city)
# print(length)
# ```
# </details>

# %% [markdown]
# ## 5. Core Practice: The Email Generator
#
# **Difficulty:** Medium
#
# **Goal:** String concatenation with multiple variables.
#
# **Task:** Generate a company email address.
# 1. Ask for the First Name.
# 2. Ask for the Last Name.
# 3. Ask for the Company Name.
# 4. Print the result in the format: `lastname.firstname@company.com`
#
# *Note: Don't worry about lowercase letters yet, just combine the strings exactly as entered.*

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# first = input("First Name: ")
# last = input("Last Name: ")
# company = input("Company: ")
#
# print(last + "." + first + "@" + company + ".com")
# ```
# </details>

# %% [markdown]
# ## 6. The Boss: Social Media Profile Card
#
# **Difficulty:** Hard
#
# **Goal:** Combine all Day 1 concepts: Input, Variables, Newlines, and Concatenation.
#
# **Task:** Create a program that generates a formatted user profile card.
# 1. Ask the user for their **Handle** (username).
# 2. Ask the user for their **Bio**.
# 3. Ask the user for their **Year of Birth**.
# 4. Print a card exactly like this (assuming inputs are 'coder123', 'I love Python', and '1995'):
#
# ```text
# --------------------
# USER PROFILE
# Handle: @coder123
# Bio: I love Python
# Born: 1995
# --------------------
# ```
#
# **Requirement:** You must use variables for the inputs and construct the final print statement using `+` and `\n`.

# %%
# Write your code here

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# handle = input("Handle: ")
# bio = input("Bio: ")
# year = input("Year of Birth: ")
#
# # Creating a separator variable makes the code cleaner
# line = "--------------------"
#
# print(line + "\nUSER PROFILE\nHandle: @" + handle + "\nBio: " + bio + "\nBorn: " + year + "\n" + line)
# ```
# </details>

# %% [markdown]
# ## 7. The Debugger: Find the Bug
#
# **Type:** Debugging
#
# **Goal:** Identify Syntax and Indentation errors.
#
# **Task:** The code below is trying to create a simple Mad Libs story, but it has **3 specific errors**. Find them and fix the code so it runs.
#
# **Buggy Code:**
# ```python
# noun = input("Give me a noun: ")
# adjective = input("Give me an adjective: )
#   print("The " + adjective + " " + noun + " went to school.")
# ```

# %%
# Copy the buggy code here and fix it:

# %% [markdown]
# <details>
# <summary>Click to see the solution</summary>
#
# ```python
# # Error 1: Missing closing quote in the second input()
# # Error 2: IndentationError on the print statement (extra spaces at start)
# # Error 3: (Implicit) Ensure all parentheses are closed
#
# noun = input("Give me a noun: ")
# adjective = input("Give me an adjective: ")
# print("The " + adjective + " " + noun + " went to school.")
# ```
# </details>
